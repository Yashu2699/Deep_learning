# %% [markdown]
# <a href="https://colab.research.google.com/github/Yashu2699/Deep_learning/blob/main/object_classification/7_RESNET.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPooling2D, Add
from tensorflow.keras.layers import GlobalAveragePooling2D, Flatten, Dense

# %%
def residual_block(X_start, filters, name, reduce=False, res_conv2d=False):
    """
    Residual building block used by ResNet-50
    """
    nb_filters_1, nb_filters_2, nb_filters_3 = filters
    strides_1 = [2,2] if reduce else [1,1]
        
    X = Conv2D(filters=nb_filters_1, kernel_size=[1,1], strides=strides_1, padding='same', name=name)(X_start)
    X = BatchNormalization()(X)      # default axis-1 is ok
    X = Activation('relu')(X)
    
    X = Conv2D(filters=nb_filters_2, kernel_size=[3,3], strides=[1,1], padding='same')(X)
    X = BatchNormalization()(X)
    X = Activation('relu')(X)
    
    X = Conv2D(filters=nb_filters_3, kernel_size=[1,1], strides=[1,1], padding='same')(X)
    X = BatchNormalization()(X)
    
    if res_conv2d:
        X_res = Conv2D(filters=nb_filters_3, kernel_size=[1,1], strides=strides_1, padding='same')(X_start)
        X_res = BatchNormalization()(X_res)
    else:
        X_res = X_start
        
    X = Add()([X, X_res])
    X = Activation('relu')(X)
    return X

# %%
def resnet50(input_shape, nb_classes):
    assert len(input_shape) == 3
    
    X_input = Input(shape=input_shape)

    # conv1
    X = Conv2D(filters=64, kernel_size=[7,7], strides=[2,2], padding='same', name='conv1')(X_input)
    X = BatchNormalization(name='bn_conv1')(X)
    X = Activation('relu')(X)
    X = MaxPooling2D([3,3], strides=[2,2])(X)

    # conv2_x
    X = residual_block(X, filters=[64, 64, 256], name='conv2_a', reduce=False, res_conv2d=True)
    X = residual_block(X, filters=[64, 64, 256], name='conv2_b')
    X = residual_block(X, filters=[64, 64, 256], name='conv2_c')

    # conv3_x
    X = residual_block(X, filters=[128, 128, 512], name='conv3_a', reduce=True, res_conv2d=True)
    X = residual_block(X, filters=[128, 128, 512], name='conv3_b')
    X = residual_block(X, filters=[128, 128, 512], name='conv3_c')
    X = residual_block(X, filters=[128, 128, 512], name='conv3_d')

    # conv4_x
    X = residual_block(X, filters=[256, 256, 1024], name='conv4_a', reduce=True, res_conv2d=True)
    X = residual_block(X, filters=[256, 256, 1024], name='conv4_b')
    X = residual_block(X, filters=[256, 256, 1024], name='conv4_c')
    X = residual_block(X, filters=[256, 256, 1024], name='conv4_d')
    X = residual_block(X, filters=[256, 256, 1024], name='conv4_e')
    X = residual_block(X, filters=[256, 256, 1024], name='conv4_f')

    # conv5_x
    X = residual_block(X, filters=[512, 512, 2048], name='conv5_a', reduce=True, res_conv2d=True)
    X = residual_block(X, filters=[512, 512, 2048], name='conv5_b')
    X = residual_block(X, filters=[512, 512, 2048], name='conv5_c')

    X = GlobalAveragePooling2D(name='avg_pool')(X)
    X = Flatten()(X)
    X = Dense(units=nb_classes, activation='softmax')(X)
    
    model = tf.keras.models.Model(inputs=X_input, outputs=X)
    model.compile(optimizer=tf.keras.optimizers.Adam(lr=0.0001),
                  loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
import tensorflow as tf

model = resnet50(input_shape=[224, 224, 3], nb_classes=17)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1 (Conv2D)                 (None, 112, 112, 64  9472        ['input_1[0][0]']
#                                 )
#
#  bn_conv1 (BatchNormalization)  (None, 112, 112, 64  256         ['conv1[0][0]']
#                                 )
#
#  activation (Activation)        (None, 112, 112, 64  0           ['bn_conv1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 55, 55, 64)   0           ['activation[0][0]']
#
#  conv2_a (Conv2D)               (None, 55, 55, 64)   4160        ['max_pooling2d[0][0]']
#
#  batch_normalization (BatchNorm  (None, 55, 55, 64)  256         ['conv2_a[0][0]']
#  alization)
#
#  activation_1 (Activation)      (None, 55, 55, 64)   0           ['batch_normalization[0][0]']
#
#  conv2d (Conv2D)                (None, 55, 55, 64)   36928       ['activation_1[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 55, 55, 64)  256         ['conv2d[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 55, 55, 64)   0           ['batch_normalization_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 55, 55, 256)  16640       ['activation_2[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 55, 55, 256)  16640       ['max_pooling2d[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 55, 55, 256)  1024       ['conv2d_1[0][0]']
#  rmalization)
#
#  batch_normalization_3 (BatchNo  (None, 55, 55, 256)  1024       ['conv2d_2[0][0]']
#  rmalization)
#
#  add (Add)                      (None, 55, 55, 256)  0           ['batch_normalization_2[0][0]',
#                                                                   'batch_normalization_3[0][0]']
#
#  activation_3 (Activation)      (None, 55, 55, 256)  0           ['add[0][0]']
#
#  conv2_b (Conv2D)               (None, 55, 55, 64)   16448       ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 55, 55, 64)  256         ['conv2_b[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 55, 55, 64)   0           ['batch_normalization_4[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 55, 55, 64)   36928       ['activation_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 55, 55, 64)  256         ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 55, 55, 64)   0           ['batch_normalization_5[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 55, 55, 256)  16640       ['activation_5[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 55, 55, 256)  1024       ['conv2d_4[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 55, 55, 256)  0           ['batch_normalization_6[0][0]',
#                                                                   'activation_3[0][0]']
#
#  activation_6 (Activation)      (None, 55, 55, 256)  0           ['add_1[0][0]']
#
#  conv2_c (Conv2D)               (None, 55, 55, 64)   16448       ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 55, 55, 64)  256         ['conv2_c[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 55, 55, 64)   0           ['batch_normalization_7[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 55, 55, 64)   36928       ['activation_7[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 55, 55, 64)  256         ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 55, 55, 64)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 55, 55, 256)  16640       ['activation_8[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 55, 55, 256)  1024       ['conv2d_6[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 55, 55, 256)  0           ['batch_normalization_9[0][0]',
#                                                                   'activation_6[0][0]']
#
#  activation_9 (Activation)      (None, 55, 55, 256)  0           ['add_2[0][0]']
#
#  conv3_a (Conv2D)               (None, 28, 28, 128)  32896       ['activation_9[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 28, 28, 128)  512        ['conv3_a[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_10[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 28, 28, 128)  147584      ['activation_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 28, 28, 128)  512        ['conv2d_7[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_11[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 28, 28, 512)  66048       ['activation_11[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 28, 28, 512)  131584      ['activation_9[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_8[0][0]']
#  ormalization)
#
#  batch_normalization_13 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_9[0][0]']
#  ormalization)
#
#  add_3 (Add)                    (None, 28, 28, 512)  0           ['batch_normalization_12[0][0]',
#                                                                   'batch_normalization_13[0][0]']
#
#  activation_12 (Activation)     (None, 28, 28, 512)  0           ['add_3[0][0]']
#
#  conv3_b (Conv2D)               (None, 28, 28, 128)  65664       ['activation_12[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 28, 28, 128)  512        ['conv3_b[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_14[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 28, 28, 128)  147584      ['activation_13[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 28, 28, 128)  512        ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_15[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 28, 28, 512)  66048       ['activation_14[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_11[0][0]']
#  ormalization)
#
#  add_4 (Add)                    (None, 28, 28, 512)  0           ['batch_normalization_16[0][0]',
#                                                                   'activation_12[0][0]']
#
#  activation_15 (Activation)     (None, 28, 28, 512)  0           ['add_4[0][0]']
#
#  conv3_c (Conv2D)               (None, 28, 28, 128)  65664       ['activation_15[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 28, 28, 128)  512        ['conv3_c[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_17[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 28, 28, 128)  147584      ['activation_16[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 28, 28, 128)  512        ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_18[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 28, 28, 512)  66048       ['activation_17[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_13[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 28, 28, 512)  0           ['batch_normalization_19[0][0]',
#                                                                   'activation_15[0][0]']
#
#  activation_18 (Activation)     (None, 28, 28, 512)  0           ['add_5[0][0]']
#
#  conv3_d (Conv2D)               (None, 28, 28, 128)  65664       ['activation_18[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 28, 28, 128)  512        ['conv3_d[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_20[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 28, 28, 128)  147584      ['activation_19[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 28, 28, 128)  512        ['conv2d_14[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_21[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 28, 28, 512)  66048       ['activation_20[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_15[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 28, 28, 512)  0           ['batch_normalization_22[0][0]',
#                                                                   'activation_18[0][0]']
#
#  activation_21 (Activation)     (None, 28, 28, 512)  0           ['add_6[0][0]']
#
#  conv4_a (Conv2D)               (None, 14, 14, 256)  131328      ['activation_21[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 14, 14, 256)  1024       ['conv4_a[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_23[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_22[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_24[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 14, 14, 1024  263168      ['activation_23[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 14, 14, 1024  525312      ['activation_21[0][0]']
#                                 )
#
#  batch_normalization_25 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_17[0][0]']
#  ormalization)                  )
#
#  batch_normalization_26 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_18[0][0]']
#  ormalization)                  )
#
#  add_7 (Add)                    (None, 14, 14, 1024  0           ['batch_normalization_25[0][0]',
#                                 )                                 'batch_normalization_26[0][0]']
#
#  activation_24 (Activation)     (None, 14, 14, 1024  0           ['add_7[0][0]']
#                                 )
#
#  conv4_b (Conv2D)               (None, 14, 14, 256)  262400      ['activation_24[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 14, 14, 256)  1024       ['conv4_b[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_27[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_25[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_19[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_28[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 14, 14, 1024  263168      ['activation_26[0][0]']
#                                 )
#
#  batch_normalization_29 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_20[0][0]']
#  ormalization)                  )
#
#  add_8 (Add)                    (None, 14, 14, 1024  0           ['batch_normalization_29[0][0]',
#                                 )                                 'activation_24[0][0]']
#
#  activation_27 (Activation)     (None, 14, 14, 1024  0           ['add_8[0][0]']
#                                 )
#
#  conv4_c (Conv2D)               (None, 14, 14, 256)  262400      ['activation_27[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 14, 14, 256)  1024       ['conv4_c[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_30[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_28[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_31[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 14, 14, 1024  263168      ['activation_29[0][0]']
#                                 )
#
#  batch_normalization_32 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_22[0][0]']
#  ormalization)                  )
#
#  add_9 (Add)                    (None, 14, 14, 1024  0           ['batch_normalization_32[0][0]',
#                                 )                                 'activation_27[0][0]']
#
#  activation_30 (Activation)     (None, 14, 14, 1024  0           ['add_9[0][0]']
#                                 )
#
#  conv4_d (Conv2D)               (None, 14, 14, 256)  262400      ['activation_30[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 14, 14, 256)  1024       ['conv4_d[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_33[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_31[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_34[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 14, 14, 1024  263168      ['activation_32[0][0]']
#                                 )
#
#  batch_normalization_35 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_24[0][0]']
#  ormalization)                  )
#
#  add_10 (Add)                   (None, 14, 14, 1024  0           ['batch_normalization_35[0][0]',
#                                 )                                 'activation_30[0][0]']
#
#  activation_33 (Activation)     (None, 14, 14, 1024  0           ['add_10[0][0]']
#                                 )
#
#  conv4_e (Conv2D)               (None, 14, 14, 256)  262400      ['activation_33[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 14, 14, 256)  1024       ['conv4_e[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_36[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_34[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_37[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 14, 14, 1024  263168      ['activation_35[0][0]']
#                                 )
#
#  batch_normalization_38 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_26[0][0]']
#  ormalization)                  )
#
#  add_11 (Add)                   (None, 14, 14, 1024  0           ['batch_normalization_38[0][0]',
#                                 )                                 'activation_33[0][0]']
#
#  activation_36 (Activation)     (None, 14, 14, 1024  0           ['add_11[0][0]']
#                                 )
#
#  conv4_f (Conv2D)               (None, 14, 14, 256)  262400      ['activation_36[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 14, 14, 256)  1024       ['conv4_f[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_39[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_37[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_38 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_40[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 14, 14, 1024  263168      ['activation_38[0][0]']
#                                 )
#
#  batch_normalization_41 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_28[0][0]']
#  ormalization)                  )
#
#  add_12 (Add)                   (None, 14, 14, 1024  0           ['batch_normalization_41[0][0]',
#                                 )                                 'activation_36[0][0]']
#
#  activation_39 (Activation)     (None, 14, 14, 1024  0           ['add_12[0][0]']
#                                 )
#
#  conv5_a (Conv2D)               (None, 7, 7, 512)    524800      ['activation_39[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 7, 7, 512)   2048        ['conv5_a[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 7, 7, 512)    0           ['batch_normalization_42[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 7, 7, 512)    2359808     ['activation_40[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 7, 7, 512)    0           ['batch_normalization_43[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 7, 7, 2048)   1050624     ['activation_41[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 7, 7, 2048)   2099200     ['activation_39[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 7, 7, 2048)  8192        ['conv2d_30[0][0]']
#  ormalization)
#
#  batch_normalization_45 (BatchN  (None, 7, 7, 2048)  8192        ['conv2d_31[0][0]']
#  ormalization)
#
#  add_13 (Add)                   (None, 7, 7, 2048)   0           ['batch_normalization_44[0][0]',
#                                                                   'batch_normalization_45[0][0]']
#
#  activation_42 (Activation)     (None, 7, 7, 2048)   0           ['add_13[0][0]']
#
#  conv5_b (Conv2D)               (None, 7, 7, 512)    1049088     ['activation_42[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 7, 7, 512)   2048        ['conv5_b[0][0]']
#  ormalization)
#
#  activation_43 (Activation)     (None, 7, 7, 512)    0           ['batch_normalization_46[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 7, 7, 512)    2359808     ['activation_43[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_32[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 7, 7, 512)    0           ['batch_normalization_47[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 7, 7, 2048)   1050624     ['activation_44[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 7, 7, 2048)  8192        ['conv2d_33[0][0]']
#  ormalization)
#
#  add_14 (Add)                   (None, 7, 7, 2048)   0           ['batch_normalization_48[0][0]',
#                                                                   'activation_42[0][0]']
#
#  activation_45 (Activation)     (None, 7, 7, 2048)   0           ['add_14[0][0]']
#
#  conv5_c (Conv2D)               (None, 7, 7, 512)    1049088     ['activation_45[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 7, 7, 512)   2048        ['conv5_c[0][0]']
#  ormalization)
#
#  activation_46 (Activation)     (None, 7, 7, 512)    0           ['batch_normalization_49[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 7, 7, 512)    2359808     ['activation_46[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_47 (Activation)     (None, 7, 7, 512)    0           ['batch_normalization_50[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 7, 7, 2048)   1050624     ['activation_47[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 7, 7, 2048)  8192        ['conv2d_35[0][0]']
#  ormalization)
#
#  add_15 (Add)                   (None, 7, 7, 2048)   0           ['batch_normalization_51[0][0]',
#                                                                   'activation_45[0][0]']
#
#  activation_48 (Activation)     (None, 7, 7, 2048)   0           ['add_15[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 2048)        0           ['activation_48[0][0]']
#  2D)
#
#  flatten (Flatten)              (None, 2048)         0           ['avg_pool[0][0]']
#
#  dense (Dense)                  (None, 17)           34833       ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 23,622,545
# Trainable params: 23,569,425
# Non-trainable params: 53,120
# __________________________________________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
